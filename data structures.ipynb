# %%
#if-elif-else
marks = int(input("marks : "))
if(marks >= 90):
    print("A")
elif(marks >= 80 and marks < 90):
    print("B")
elif(marks >= 70 and marks < 80):
    print("C")
else:
    print("D")
# Out:
# marks :  89
# B

# %%
# if-elif-else
light = input("light:")
if(light == "red"):
    print("stop")
elif(light == "green"):
    print("go")
elif(light == "yellow"):
    print("look")
else:
    print("light is brocken")
# Out:
# light: yellow
# look

# %%
A = int(input("A : "))
G = input("M/F : ")

if (A == 1 or A == 2) and G == "M":
    print("fee is 100")
elif (A == 3 or A == 4) and G == "F":
    print("fee is 200")
elif A == 5 and G == "M":
    print("fee is 300")
else:
    print("no fee")
# Out:
# A :  1
# M/F :  M
# fee is 100

# %%
# single if
food = input("food : ")
eat = "yes" if food == "cake" else "no"
print(eat)
# Out:
# food :  carrot
# no

# %%
food = input("food : ")
eat = "yes" if food == "cake" or food == "chocholate" else "no sweet"
print(eat)
# Out:
# food :  carrot
# no sweet

# %%
#clever if/ternary operator
<var> = (false_val,true_val) [<condition>]
age = int(input("age ;")

# %%
# arithmetic operator
a = 4
b = 2

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
# Out:
# 6
# 2
# 8
# 2.0
# 2

# %%
# relational operator
a = 2
b = 4

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#assignment operator
a = 60
a += 10
print("a :", a)
a -= 5
print("a :", a)
a *= 10
print("a :", a)
a /= 10
print("a :", a)
a %= 10
print("a :", a)
a **= 10
print("a :", a)
# Out:
# a : 70
# a : 65
# a : 650
# a : 65.0
# a : 5.0
# a : 9765625.0

# %%
#logical operator
x =10
y = 20
print(not x < y)

a = True
b = False
print(a and b)
print(a or b)
# Out:
# False
# False
# True

# %%
#type conversion
a = 2
b = 4
sum = a + b
print(sum)

x = int("5")
y = 4
print(type(x))
print(x + y)
# Out:
# 6
# <class 'int'>
# 9

# %%
# input in python
age = input("enter your age")
print("you entered :",age)
# Out:
# enter your age 21
# you entered : 21

# %%
val = (input("enter some value:"))
print(type(val),val)
# Out:
# enter some value: sangeeta
# <class 'str'> sangeeta

# %%
name = input("enter your name:")
division = input("enter your division:")
marks = input("enter yoyr marks:")
print("welcome",name)
print("age =",age)
print("marks =",marks)
# Out:
# enter your name: sangeeta
# enter your division: B
# enter yoyr marks: 77
# welcome sangeeta
# age = 21
# marks = 77

# %%
#write a input of 2 numbers and print their sum
irst = int(input("enter first number:"))
second = int(input("enter second number:"))
print("sum =",(first + second))
# Out:
# enter first number: 3
# enter second number: 2
# sum = 5

# %%
#WAP  to input side of a square and print its area
side = float(input("enter a side:"))
print("area =",side * side)
# Out:
# enter a side: 3.3
# area = 10.889999999999999

# %%
# WAP to input 2 floating point numbers and print their average
a = float(input("enter first :"))
b = float(input("enter second :"))
          
print("avg =", (a+b)/2 )
# Out:
# enter first : 3.4
# enter second : 2.3
# avg = 2.8499999999999996

# %%
# WAP to input 2 int numbers,a and b.
#print True if a is greater than or equal to b.if not print False
a = int(input("enter a :"))
b = int(input("enter b :"))
if a >= b:
    print("True")
else:
    print("False")
# Out:
# enter a : 12
# enter b : 10
# True

# %%
a = int(input("enter a :"))
b = int(input("enter b :"))
print(a >= b)
# Out:
# enter a : 2
# enter b : 15
# False

# %%
str1 = "this is a string.\nwe are creating it in python."
print(str1)
# Out:
# this is a string.
# we are creating it in python.

# %%
str1="sangeeta"
len1=len(str1)
print(len1)

str2="kolur"
len2=len(str2)
print(len2)

final_str=str1+" "+str2
print(final_str)
print(len(final_str))
# Out:
# 8
# 5
# sangeeta kolur
# 14

# %%
# indexing
str = "sangeeta"
print(str[2])
print(str[6])
# Out:
# n
# t

# %%
#slicing
str="sangeetakolur"
print(str[1:4])
print(str[:5])
print(str[1:])
print(str[0:])
print(str[:-4])
print(str[-1:])
print(str[3:8])

#negative index
str="Apple"
print(str[-3:-1])
# Out:
# ang
# sange
# angeetakolur
# sangeetakolur
# sangeetak
# r
# geeta
# pl

# %%
# string function
str="i am studing python from apnacollege"
print(str.endswith("ege"))
str=str.capitalize()
print(str.replace("o","a"))
print(str.replace("python","java"))
print(str.find("o"))
print(str.find("p"))
print(str.count("from"))
# Out:
# True
# I am studing pythan fram apnacallege
# I am studing java from apnacollege
# 17
# 13
# 1

# %% [markdown]
# # practice

# %%
#WAP to input user's first name and print its length
name=input("enter the first name :")
print("first name :",name)
print(len(name))
# Out:
# enter the first name : sangeeta
# first name : sangeeta
# 8

# %%
#WAP to find occarance of "s" in a string
str="sushmita"
print(str.count("s"))
# Out:
# 2

# %% [markdown]
# # conditional staements

# %%
# if-else
age=int(input("enter your age :"))
if age>=18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# enter your age : 12
# you are not eligible to vote

# %%
# if-elif-else
age=int(input("enter your age :"))
if age>=18:
    print("you are eligible to vote")
elif age<18 and age>6:
    print("you are a minor")
else:
    print("you are not eligible to vote")
# Out:
# enter your age : 5
# you are not eligible to vote

# %%
marks=int(input("enter your marks :"))
if marks>=90:
    print("grade A ")
elif (90>marks>=80):
    print("grade B ")
elif (80>marks>=70):
    print("grade C ")
else:
    print("grade D ")
# Out:
# enter your marks : 78
# grade C

# %%
#nesting
age=int(input("enter age:"))
if(age>=18):
        if(age>=70):
            print("cannot drive")
        else:
            print("can drive")
else:
    print("cannot drive")
# Out:
# enter age: 15
# cannot drive

# %% [markdown]
# # practice

# %%
# WAP to check if a number entered by the user is odd or even
num=int(input("enter number :"))
if (num % 2 == 0):
    print("even")
else:
    print("odd")
# Out:
# enter number : 7
# odd

# %%
#WAP to find the greatest of 3 numbers entered by user
num1=int(input("enter number1 :"))
num2=int(input("enter number2 :"))
num3=int(input("enter number3 :"))
if (num1>num2):
    print("num1 is greater")
elif(num2>num3):
    print("num2 is greater")
elif(num3>num1):
    print("num3 is greater")
else:
    print("not found")
# Out:
# enter number1 : 4
# enter number2 : 5
# enter number3 : 7
# num3 is greater

# %%
#WAP to find the greatest of 3 numbers entered by user
a=int(input("enter a :"))
b=int(input("enter b :"))
c=int(input("enter c :"))
if(a>=b and a>=c):
    print("a is greater")
elif(b>=c):
    print("b is greater")
else:
    print("c is greater")
# Out:
# enter a : 4
# enter b : 5
# enter c : 6
# c is greater

# %%
#WAP to check if a number is a multiple of 7 or not
x = int(input("enter number :"))
if(x % 7 == 0):
    print("this is multiple of 7")
else:
    print("this is not multiple of 7")
# Out:
# enter number : 23
# this is not multiple of 7

# %%
#list in pyton 
marks=[34,45,68,98]
print(marks)
print(type(marks))
print(marks[2])
print(len(marks))
print(marks[0])
marks[0] = "pass"
print(marks)
#list slicing
print(marks[0:3])
# Out:
# [34, 45, 68, 98]
# <class 'list'>
# 68
# 4
# 34
# ['pass', 45, 68, 98]
# ['pass', 45, 68]

# %%
#list methods
name=["sihi","sangeeta","geeta","priya"]
name.append("diya")
print(name)
name.sort()
print(name)
name.reverse()
print(name)
name.sort(reverse = True)
print(name)
name.insert(4,"shree")
print(name)
name.pop(2)
print(name)
list=[3,2,5]
list.sort()
print(list)
# Out:
# ['sihi', 'sangeeta', 'geeta', 'priya', 'diya']
# ['diya', 'geeta', 'priya', 'sangeeta', 'sihi']
# ['sihi', 'sangeeta', 'priya', 'geeta', 'diya']
# ['sihi', 'sangeeta', 'priya', 'geeta', 'diya']
# ['sihi', 'sangeeta', 'priya', 'geeta', 'shree', 'diya']
# ['sihi', 'sangeeta', 'geeta', 'shree', 'diya']
# [2, 3, 5]

# %%
#tuples in pyton
tup=(2,1,3,4)
print(tup)
print(type(tup))
print(tup[0])
tup1=(1,1,3,6)
print(tup1)
print(tup1.index(3))
print(tup1.count(1))
# Out:
# (2, 1, 3, 4)
# <class 'tuple'>
# 2
# (1, 1, 3, 6)
# 2
# 2

# %% [markdown]
# # practice

# %%
# WAP to ask the user to enter names of their favorite movies and store them in a list
movie = []
mv1=input("enter 1st favorate movie :")
mv2=input("enter 2nd favorate movie :")
mv3=input("enter 3rd favorate movie :")
movie.append(mv1)
movie.append(mv2)
movie.append(mv3)
print(movie)
# Out:
# enter 1st favorate movie : radha
# enter 2nd favorate movie : krishna
# enter 3rd favorate movie : tulasi
# ['radha', 'krishna', 'tulasi']

# %%
#WAP to check if a list contains a palindrome of elements.
list1=[1,2,1]
list2=[1,2,3]
copy_list1 = list.copy()
copy_list1.reverse()
if(copy_list1 == list1):
    print("palindrome")

# %%
#wap to count the number of students with the "A" grade in the following tuple
grade = ["C","D","A","A","B","B","A"]
print(grade.count("A"))
# Out:
# 3

# %%
#store above values in a list and sort them from "A" to "D"
grade=["C","D","A","A","B","B","A"]
grade.sort()
print(grade)
# Out:
# ['A', 'A', 'A', 'B', 'B', 'C', 'D']

# %%
# dictionaries
info = {
    "key":"value",
    "name":"sangeeta",
    "learning":"coding",
    "subject":["python","c","java"],
    "topic":{"list","dict"}
}
print(info)
# Out:
# {'key': 'value', 'name': 'sangeeta', 'learning': 'coding', 'subject': ['python', 'c', 'java'], 'topic': {'list', 'dict'}}

# %%
#nested dictionaries
info={
    "name":"raksha",
    "subject":{
        "phy":78,
        "chem":75,
        "math":85
    }
}
print(info)
# Out:
# {'name': 'raksha', 'subject': {'phy': 78, 'chem': 75, 'math': 85}}

# %%
# dictionaries
info={
    "name":"raksha",
    "subject":{
        "phy":78,
        "chem":75,
        "math":85
    }
}
print(info.keys())
print(list(info.keys()))
print(len(info))

print(info.values())
print(list(info.values()))

print(info.items())
pairs = list(info.items())
print(pairs[0])

print(info.get("name"))

info.update({"city" : "gadag","age" : 18})
print(info)
# Out:
# dict_keys(['name', 'subject'])
# ['name', 'subject']
# 2
# dict_values(['raksha', {'phy': 78, 'chem': 75, 'math': 85}])
# ['raksha', {'phy': 78, 'chem': 75, 'math': 85}]
# dict_items([('name', 'raksha'), ('subject', {'phy': 78, 'chem': 75, 'math': 85})])
# ('name', 'raksha')
# raksha
# {'name': 'raksha', 'subject': {'phy': 78, 'chem': 75, 'math': 85}, 'city': 'gadag', 'age': 18}

# %%
#set
collection = {1,2,3,4,3,"sangeeta","kolur"} #repeated elements stored only once
print(type(collection))
print(collection)
print(len(collection))
# Out:
# <class 'set'>
# {1, 2, 3, 4, 'sangeeta', 'kolur'}
# 6

# %%
collection = set()
print(type(collection))

collection = set()
collection.add(1)
print(type(collection))
# Out:
# <class 'set'>
# <class 'set'>

# %%
# set methods
student = {"asha","ggg","A",7,13}
student.remove(7)
print(student)
student.add(5)
print(student)
student.add((1,2,3))
print(student)
student.clear()
print(len(student))

collection = {"radha","geeta","chetana","kavana"}
print(collection.pop())

set1 = {1,2,3}
set2 = {2,3,4}

final_set = set1.union(set2)
print(final_set)

final_set1 =set1.intersection(set2)
print(final_set1)
# Out:
# {'A', 'ggg', 'asha', 13}
# {'A', 5, 'ggg', 'asha', 13}
# {'A', 5, 'ggg', 'asha', (1, 2, 3), 13}
# 0
# radha
# {1, 2, 3, 4}
# {2, 3}

# %% [markdown]
# # practice

# %%
# store follwing word meaning in a python dictionary
things = {}
print(type(things))
things.update({"table":["a piece of furniture" ,
               "list of facts and figure"],
               "cat" : "a small animal"
              })
print(things)
# Out:
# <class 'dict'>
# {'table': ['a piece of furniture', 'list of facts and figure'], 'cat': 'a small animal'}

# %%
#we are given a list of subject s for students.
#assume one classroom is required for1 subject.
#how many classrooms are needed by all students
subject = {"python","java","c++","python","javascript","java","python","java","c++","C"}
set = ("python","java","c++","c","javascript")
print(set)
print(len(set))
# Out:
# ('python', 'java', 'c++', 'c', 'javascript')
# 5

# %%
#wap to enter marks of 3 subjects from the user and store them in a dictionariy.
#start with an empty dictionary and add one by one.
#use subject name as key and marks as value.

sub1 = int(input("enter a sub1 marks :"))
sub2 = int(input("enter a sub2 marks :"))
sub3 = int(input("enter a sub3 marks :"))
student = {}
student = {"chem" : sub1,"phy" : sub2,"bio" : sub3}
print(student)

marks = {}
x = int(input("enter chem : "))
marks.update({"chem" : x })

y = int(input("emnter phy  : "))
marks.update({"phy" : y })

z = int(input("enter bio : "))
marks.update({"bio" : z })

print(marks)
# Out:
# enter a sub1 marks : 77
# enter a sub2 marks : 88
# enter a sub3 marks : 99
# {'chem': 77, 'phy': 88, 'bio': 99}
# enter chem :  89
# emnter phy  :  98
# enter bio :  99
# {'chem': 89, 'phy': 98, 'bio': 99}

# %%
#figure out a way to store 9 and 9.0 as seperate valuue in set.
#you can take help of built in data types
values = {"9",9.0}
print(values)

values1 = {float:("9.0"),
            int:("9")}
print(values1)
# Out:
# {9.0, '9'}
# {<class 'float'>: '9.0', <class 'int'>: '9'}
