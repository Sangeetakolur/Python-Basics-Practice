# %%
import random

randNum=random.randint(1, 5)
print(randNum)
# Out:
# 1

# %% [markdown]
# # Guess the number

# %%
import random   # <-- Missing import

target = random.randint(1, 5)

while True:
    try:
        userChoice = int(input("Guess the target (1-5): "))

        if userChoice == target:
            print("Success: Correct Guess!!")
            break
        elif userChoice < target:
            print("Your number was too small. Take a bigger guess...")
        else:
            print("Your number was too big. Take a smaller guess...")

    except ValueError:
        print("Please enter a valid number!")

print("------- GAME OVER -------")
# Out:
# Guess the target (1-5):  1
# Your number was too small. Take a bigger guess...
# Guess the target (1-5):  2
# Your number was too small. Take a bigger guess...
# Guess the target (1-5):  3
# Your number was too small. Take a bigger guess...
# Guess the target (1-5):  4
# Your number was too small. Take a bigger guess...
# Guess the target (1-5):  5
# Success: Correct Guess!!
# ------- GAME OVER -------

# %%
import random
target=random.randint(1, 100)

while True:
    userChoice=int(input("Guess the target :"))
    if(userChoice == target):
        print("Success : Correct Guess!!")
        break
    elif(userChoice < target):
        print("your number was too small.Take a bigger guess...")
    else:
        print("your number was too big.Take a smaller guess...")
        
    
    
print("-------GAME OVER-------")
# Out:
# Guess the target : 50
# your number was too small.Take a bigger guess...
# Guess the target : 70
# your number was too small.Take a bigger guess...
# Guess the target : 80
# your number was too small.Take a bigger guess...
# Guess the target : 90
# your number was too small.Take a bigger guess...
# Guess the target : 95
# Success : Correct Guess!!
# -------GAME OVER-------

# %% [markdown]
# # random password generator

# %%
import random

val=random.choice(['a','b','c','d'])
print(val)
# Out:
# b

# %%
import random
import string

length = int(input("Enter password length: "))

# Combine all character types
characters = string.ascii_letters + string.digits + string.punctuation

password = "".join(random.choice(characters) for _ in range(length))

print("Generated Password:", password)
# Out:
# Enter password length:  5
# Generated Password: M>t{O

# %%
import secrets
import string

length = 12   # Set password length here

characters = string.ascii_letters + string.digits + string.punctuation
password = "".join(secrets.choice(characters) for _ in range(length))

print("Generated Password:", password)
# Out:
# Generated Password: [']Algz=22]>QC']
