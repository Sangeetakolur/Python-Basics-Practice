# %%
# functions in python
def sum(a,b):
    s = a + b
    return s
print(sum(2,3))
# Out:
# 5

# %%
def calc_sum(a,b):
    sum = a + b
    print(sum)
    return sum

calc_sum(5, 10)
# Out:
# 15
# 15

# %%
#average of 3 numbers
def calc_avg(a,b,c):
    sum = a + b + c
    avg = sum / 3
    print(avg)
    return avg
calc_avg(6,4,5)
# Out:
# 5.0
# 5.0

# %%
print("sangeeta",end=" ")
print("kolur")
# Out:
# sangeeta kolur

# %%
def calc_mul(a,b):
    mul = a*b
    print(mul)
    return(mul)
calc_mul(2,3)
# Out:
# 6
# 6

# %% [markdown]
# # practice quations

# %%
# WAF to print the length of a list(list is a parameter)
num = [1,2,3,4,56,87]

def print_len(list):
    print(len(list))

print_len(num)
# Out:
# 6

# %%
#WAF to find factorial of n.(n is a parameter)

def cal_fact(n):
    fact = 1
    for i in range(1,n+1):
        fact *= i
    print(fact)
cal_fact(5)
# Out:
# 120

# %%
# WAF to convert USD to INR
def converter(usd_val):
    inr_val = usd_val * 83
    print(usd_val,"USD=",inr_val,"INR")
converter(2)
# Out:
# 2 USD= 166 INR

# %%
#recursive function
def show(n):
    if(n == 0):
        return
    print(n)
    show(n-1)

show(6)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # Recursion

# %%
def show(n):
    if(n==0):
        return
    print(n)
    show(n-1)
    print("END")
show(3)
# Out:
# 3
# 2
# 1
# END
# END
# END

# %%
def fact(n):
    if(n==0 or n==1):
        return 1
    else:
        return n*fact(n-1)
print(fact(3))
# Out:
# 6

# %% [markdown]
# # Practice question

# %%
#write a recursive program to calculate the sum of first n natural numbers
def calc_sum(n):
    if(n==0):
         return 0
    return calc_sum(n - 1) + n

sum = calc_sum(5)
print(sum)
# Out:
# 15

# %%
#write a recursive function to print all elements in a list.
#hint:use list and index as parameter
def print_list(list,index=0):
    if(index == len(list)):
        return
    print(list[index])
    print_list(list,index+1)

fruits = ["apple","lemon","banana"]
print_list(fruits)
# Out:
# apple
# lemon
# banana

# %% [markdown]
# # file i\o

# %%
#create a new "practice.txt"using python.add the following data in it:
with open("practice.txt","w") as f:
    f.write("Hi every one\nwe are learning file i\o")
    f.write("\nusing python.\nI like programming in python.")

# %%
#WAF that occarances of "python" with "java" in above file
with open("practice.txt","r") as f:
    data = f.read()

new_data = data.replace("python","java")
print(new_data)

with open("practice.txt","w") as f:
    f.write(new_data)
# Out:
# Hi every one
# we are learning file i\o
# using java.
# I like programming in java.

# %%
word = "learning"
with open("practice.txt","r")as f:
    data = f.read()
    if(data.find(word) != -1):
        print("found")
    else:
        print("not found")
# Out:
# found

# %%
#WAF to find in which line of the file does the word "learning" occur first,print -1 if word not found 
def check_for_line():
    word = "learning"
    data = True
    line_no = 1
    with open("practice.txt","r")as f:
        while data:
            data = f.readline()
            if(word in data):
                print(line_no)
                return
            line_no += 1

    return -1
check_for_line()
# Out:
# 2

# %%
#from a file containing numbers separated bybcomma,print the count of even numbers
with open("practice1.txt", "w")as f:
    f.write(["19,22,33,44,55])
    
with open("practice1.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# -----------------------------------------------------------
# TypeError                 Traceback (most recent call last)
# Cell In[72], line 3
#       1 #from a file containing numbers separated bybcomma,print the count of even numbers
#       2 with open("practice1.txt", "w")as f:
# ----> 3     f.write([19,22,33,44,55])
#       5 with open("practice1.txt", "r") as f:
#       6     data = f.read()
#
# TypeError: write() argument must be str, not list

# %%
count = 0

with open("practice1.txt", "r") as f:
    data = f.read()
    nums = data.split(",")

    for val in nums:
        val = val.strip()      # remove spaces/newlines
        if val:                # skip empty values
            if int(val) % 2 == 0:
                count += 1

print(count)
# Out:
# -----------------------------------------------------------
# ValueError                Traceback (most recent call last)
# Cell In[71], line 10
#       8         val = val.strip()      # remove spaces/newlines
#       9         if val:                # skip empty values
# ---> 10             if int(val) % 2 == 0:
#      11                 count += 1
#      13 print(count)
#
# ValueError: invalid literal for int() with base 10: '[19'
